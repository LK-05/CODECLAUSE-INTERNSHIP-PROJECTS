# %% [markdown]
# Project ID - #CC3605
#
# Project Title - Natural Language Processing for Legal Documents
#
# Internship Domain - Artificial Intelligence Intern
#
# Project Level - Golden Level
#
# Assigned By- CodeClause Internship
#
# Assigned To- Lakshmipriya K
#
# Start Date - 01 Oct 2024
#
# End Date - 31 Oct 2024
#
# Project Details-
#
# Aim -
# Develop an AI system that can extract and summarize key legal information from
# complex legal documents.
#
# Description-
# Implement advanced NLP techniques to process and understand legal language,
# identify key clauses, and generate concise summaries.
#
# Technologies-
# Python, SpaCy or NLTK, Transformers
# You can use other technologies that you know.
#
# What You Learn-
# Advanced NLP, information extraction, document summarization.

# %%
# !pip install spacy transformers python-docx
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 43.9 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-82e69f35-8a4f-4c89-94d9-704427ef58f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82e69f35-8a4f-4c89-94d9-704427ef58f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import docx
def read_docx(file):
    doc = docx.Document(file)
    return ' '.join([para.text for para in doc.paragraphs])

# %%
doc_content = read_docx('Agreement.docx')
print(doc_content)
# Out:
# Agreement This Legal Agreement is entered into on March 15, 2023 , by and between Alpha Tech Solutions (the "Company") with principal offices at 1234 Main Street, New York, NY, and Beta Enterprises(the "Client") with principal offices at 5678 Market Avenue, Los Angeles, CA. Recitals WHEREAS, the Company agrees to provide consulting services to the Client regarding software development and cloud infrastructure;  WHEREAS, the Client seeks to engage the Company for such services under the terms and conditions outlined in this Agreement;  NOW, THEREFORE, in consideration of the mutual promises and agreements contained herein, the parties agree as follows: 1. Scope of Services The Company shall perform the following services:    - Custom software development    - Cloud infrastructure deployment and management    - Technical support and maintenance  2. Compensation  The Client agrees to pay the Company a total of $50,000 for the services provided. Payments shall be made in two installments
# ...

# %%
# Preprocess the text with spaCy
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(doc_content)

# %%
# Extract named entities (e.g., organizations, dates, amounts)
entities = [(entity.text, entity.label_) for entity in doc.ents]

# %%
# Extract specific legal-related entities (organizations, dates, money, laws)
legal_info = [entity for entity in doc.ents if entity.label_ in ('ORG', 'DATE', 'MONEY', 'LAW')]

# %%
# Display extracted entities and legal information
print("All Extracted Entities:", entities)
print("Filtered Legal Information (ORG, DATE, MONEY, LAW):", legal_info)
# Out:
# All Extracted Entities: [('March 15, 2023', 'DATE'), ('Alpha Tech Solutions', 'ORG'), ('1234', 'DATE'), ('Main Street', 'FAC'), ('New York', 'GPE'), ('NY', 'ORG'), ('5678 Market Avenue', 'ORG'), ('Los Angeles', 'GPE'), ('CA', 'ORG'), ('Company', 'ORG'), ('Client', 'PERSON'), ('Client', 'PERSON'), ('1', 'CARDINAL'), ('Scope of Services The Company', 'ORG'), ('2.', 'CARDINAL'), ('Client', 'PERSON'), ('50,000', 'MONEY'), ('two', 'CARDINAL'), ('25,000', 'MONEY'), ('25,000', 'MONEY'), ('3', 'CARDINAL'), ('Client', 'PERSON'), ('4.', 'CARDINAL'), ('March 20, 2023', 'DATE'), ('March 20, 2024', 'DATE'), ("30 days'", 'DATE'), ('5', 'CARDINAL'), ('the State of New York', 'ORG'), ('6', 'CARDINAL'), ('first', 'ORDINAL'), ('New York', 'GPE'), ('7', 'CARDINAL'), ('IN WITNESS WHEREOF', 'ORG'), ('first', 'ORDINAL'), ('Alpha Tech Solutions', 'ORG'), ('John Smith', 'PERSON'), ('John Smith', 'PERSON'), ('Jane Doe', 'PERSON'), ('CFO', 'ORG'), ('Jane', 'PERSON')]
# ...

# %%
# Summarize the document using Hugging Face transformers
from transformers import pipeline
summarizer = pipeline("summarization")
summary = summarizer(doc_content, max_length=150, min_length=50, do_sample=False)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
# Display the results
print("Extracted Legal Information:", legal_info)
print("Summary of the Document:", summary[0]['summary_text'])
# Out:
# Extracted Legal Information: [March 15, 2023, Alpha Tech Solutions, 1234, NY, 5678 Market Avenue, CA, Company, Scope of Services The Company, 50,000, 25,000, 25,000, March 20, 2023, March 20, 2024, 30 days', the State of New York, IN WITNESS WHEREOF, Alpha Tech Solutions, CFO]
# Summary of the Document:  Agreement This Legal Agreement is entered into on March 15, 2023 , by and between Alpha Tech Solutions (the "Company") with principal offices at 1234 Main Street, New York, NY, and Beta Enterprises (the Client) Beta Enterprises(the "Client") agrees to pay the Company a total of $50,000 for the services provided .
